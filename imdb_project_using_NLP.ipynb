# %% [markdown]
# **Created by: ayoub touti, mohamed aziz catalan**

# %% [markdown]
# # **data scraping from imdb**

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
from textblob import TextBlob
from requests import get
from time import sleep
from random import randint
from warnings import warn
import matplotlib.pyplot as plt

# %%
pages = np.arange(1, 20, 50) 
headers = {'Accept-Language': 'en-US,en;q=0.8'} # If this is not specified, the default language is Mandarin

# %%
#initialize empty lists to store the variables scraped
titles = []
years = []
ratings = []
genres = []
runtimes = []
imdb_ratings = []
imdb_ratings_standardized = []
metascores = []
votes = []

# %%
for page in pages:
    
    #get request
    response = get("https://www.imdb.com/search/title?genres=sci-fi&" 
                   + "start=" 
                   + str(page) 
                   + "&explore=title_type,genres&ref_=adv_prv")
    
    sleep(randint(8,15))
     
    #throw warning for status codes that are not 200
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(requests, response.status_code))

    #parse the content of current iteration of request
    page_html = BeautifulSoup(response.text, 'html.parser')
        
    movie_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')
    
    #extract the 50 movies for that page
    for container in movie_containers:

        #conditional for all with metascore
        if container.find('div', class_ = 'ratings-metascore') is not None:

            #title
            title = container.h3.a.text
            titles.append(title)

            #year released
            year = container.h3.find('span', class_= 'lister-item-year text-muted unbold').text
            years.append(year)

            #rating
            rating = container.p.find('span', class_= 'certificate').text
            ratings.append(rating)

            #genre
            genre = container.p.find('span', class_ = 'genre').text
            genres.append(genre)

            #runtime
            time = container.p.find('span', class_ = 'runtime').text
            runtimes.append(time)

            #IMDB ratings
            imdb = float(container.strong.text)
            imdb_ratings.append(imdb)

            #Metascore
            m_score = container.find('span', class_ = 'metascore').text
            metascores.append(int(m_score))

            #Number of votes
            vote = container.find('span', attrs = {'name':'nv'})['data-value']
            votes.append(int(vote))

# %%
sci_fi_df = pd.DataFrame({'movie': titles,
                      'year': years,
                      'rating': ratings,
                      'genre': genres,
                      'runtime_min': runtimes,
                      'imdb': imdb_ratings,
                      'metascore': metascores,
                      'votes': votes}
                      )

sci_fi_df.loc[:, 'year'] = sci_fi_df['year'].str[-5:-1] # two more data transformations after scraping
# Drop 'ovie' bug
# Make year an int
sci_fi_df['n_imdb'] = sci_fi_df['imdb'] * 10
final_df = sci_fi_df.loc[sci_fi_df['year'] != 'ovie'] # One small issue with the scrape on these two movies so just dropping those ones.
final_df.loc[:, 'year'] = pd.to_numeric(final_df['year'])

# %%
sci_fi_df
# Out:
#                                           movie  year rating  \
# 0                Black Panther: Wakanda Forever  2022  PG-13
# 1                                    Black Adam  2022  PG-13
# 2                                 Black Panther  2018  PG-13
# 3                                          Nope  2022      R
# 4             Everything Everywhere All at Once  2022      R
# 5                        Thor: Love and Thunder  2022  PG-13
# 6                                 Strange World  2022     PG
# 7                                        Avatar  2009  PG-13
# 8                       Spider-Man: No Way Home  2021  PG-13
# 9                                  Interstellar  2014  PG-13
# 10                                         Dune  2021  PG-13
# 11                 Rogue One: A Star Wars Story  2016  PG-13
# 12                            Avengers: Endgame  2019  PG-13
# 13                                      Morbius  2022  PG-13
# 14  Doctor Strange in the Multiverse of Madness  2022  PG-13
# 15                     Jurassic World: Dominion  2022  PG-13
# 16                                    Inception  2010  PG-13
#
#                                          genre runtime_min  imdb  metascore  \
# 0       \nAction, Adventure, Drama                 161 min   7.3         67
# 1     \nAction, Adventure, Fantasy                 125 min   6.8         41
# 2      \nAction, Adventure, Sci-Fi                 134 min   7.3         88
# 3        \nHorror, Mystery, Sci-Fi                 130 min   6.9         77
# 4      \nAction, Adventure, Comedy                 139 min   8.1         81
# 5      \nAction, Adventure, Comedy                 118 min   6.3         57
# 6   \nAnimation, Action, Adventure                 102 min   5.8         65
# 7     \nAction, Adventure, Fantasy                 162 min   7.8         83
# 8     \nAction, Adventure, Fantasy                 148 min   8.3         71
# 9       \nAdventure, Drama, Sci-Fi                 169 min   8.6         74
# 10      \nAction, Adventure, Drama                 155 min   8.0         74
# 11     \nAction, Adventure, Sci-Fi                 133 min   7.8         65
# 12      \nAction, Adventure, Drama                 181 min   8.4         78
# 13     \nAction, Adventure, Horror                 104 min   5.2         35
# 14    \nAction, Adventure, Fantasy                 126 min   6.9         60
# 15     \nAction, Adventure, Sci-Fi                 147 min   5.7         38
# 16     \nAction, Adventure, Sci-Fi                 148 min   8.8         74
#
#       votes  n_imdb
# 0     91542    73.0
# 1    133827    68.0
# 2    764271    73.0
# 3    161414    69.0
# 4    240086    81.0
# 5    312375    63.0
# 6      1284    58.0
# 7   1246348    78.0
# 8    745579    83.0
# 9   1810970    86.0
# 10   626024    80.0
# 11   634772    78.0
# 12  1119643    84.0
# 13   120283    52.0
# 14   405598    69.0
# 15   149700    57.0
# 16  2337036    88.0

# %% [markdown]
# # **Reviews**

# %%
page = requests.get("https://www.imdb.com/title/tt6443346/reviews?ref_=tt_ov_rt")
soup = BeautifulSoup(page.content, "html.parser")
rev = soup.findAll('div', class_='text show-more__control')
movies = []
for movie in rev:
    movies.append(movie.text)
df_subset = pd.DataFrame()
df_subset['Black Adam']=movies

# %%
df_subset
# Out:
#                                            Black Adam
# 0   Was this script the result of a 5th grade clas...
# 1   Is there ever gonna be a character arc? Terrib...
# 2   I hoped "Black Adam" would be a decent entry i...
# 3   Thought Bland Adam was another misfire for the...
# 4   Black Adam is not without its flaws, but i sti...
# 5   Black Adam is possibly one of the most generic...
# 6   I was shocked by how much I disliked Black Ada...
# 7   Black Adam is the perfect example of how inacc...
# 8   This movie is solely for kids and teens, the r...
# 9   In the superhero movie genre I would rank this...
# 10  What a movie! The special effects are really i...
# 11  There's a moment, mid-way through this monstro...
# 12  I had such high hopes and I always enjoy The R...
# 13  Black Adam feels like a Marvel movie, except i...
# 14  No, the hierarchy of power in the DC universe ...
# 15  I had no knowledge about Black Adam prior to s...
# 16  I was looking forward to this flick, but it wa...
# 17  This is like watching Avengers without knowing...
# 18  Honestly, large parts of BLACK ADAM seem like ...
# 19  Since around late 2019, I have boycotted all s...
# 20  "The film initially received an R rating due t...
# 21  "Black Adam" is the 11th film in the DC Extend...
# 22  I knew nothing of Black Adam going in so it wa...
# 23  Black Adam is the latest film in the DCEU, and...
# 24  There's a superhero rogue packed full of rage,...

# %% [markdown]
# # **Sentiments**

# %%
df = pd.DataFrame()

# %%
df['Reviews of people']=movies

# %%
list=[]
for i in range(len(movies)):
    text=TextBlob(movies[i])
    x=text.sentiment.polarity # x between -1 and 1
    list.append(round(x,2))

# %%
sent=[]
j=[]
for j in list:
    if j>0:
        x="positive"
    elif j==0:
        x="neutre"
    else :
        x="negative"
    sent.append(x)

# %%
df['sentiment']=sent

# %%
df
# Out:
#                                     Reviews of people sentiment
# 0   Was this script the result of a 5th grade clas...  negative
# 1   Is there ever gonna be a character arc? Terrib...  negative
# 2   I hoped "Black Adam" would be a decent entry i...  positive
# 3   Thought Bland Adam was another misfire for the...  negative
# 4   Black Adam is not without its flaws, but i sti...  positive
# 5   Black Adam is possibly one of the most generic...  positive
# 6   I was shocked by how much I disliked Black Ada...  negative
# 7   Black Adam is the perfect example of how inacc...  positive
# 8   This movie is solely for kids and teens, the r...  negative
# 9   In the superhero movie genre I would rank this...  positive
# 10  What a movie! The special effects are really i...  positive
# 11  There's a moment, mid-way through this monstro...  negative
# 12  I had such high hopes and I always enjoy The R...  positive
# 13  Black Adam feels like a Marvel movie, except i...  positive
# 14  No, the hierarchy of power in the DC universe ...  positive
# 15  I had no knowledge about Black Adam prior to s...  positive
# 16  I was looking forward to this flick, but it wa...  positive
# 17  This is like watching Avengers without knowing...  negative
# 18  Honestly, large parts of BLACK ADAM seem like ...  negative
# 19  Since around late 2019, I have boycotted all s...  positive
# 20  "The film initially received an R rating due t...  positive
# 21  "Black Adam" is the 11th film in the DC Extend...  positive
# 22  I knew nothing of Black Adam going in so it wa...  positive
# 23  Black Adam is the latest film in the DCEU, and...  positive
# 24  There's a superhero rogue packed full of rage,...  positive
